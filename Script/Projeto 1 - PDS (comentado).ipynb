# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#PARTE 1

#Função para gerar o vetor de instantes (n) e o vetor com amostras de x(t), de frequência o0, em cada instante (xn).
#Para uma frequencia de amostragem constante de fs = 8191 Hz.
def generator(o0):
    oS = 2*np.pi*8192

    n = np.arange(8192)
    xn = np.sin(o0*n/8192)
    
    return n, xn

# %%
#Plotando os gráficos de tempo contínuo e de tempo discreto para as 50 primeiras amostras de x(t)
def plotting(n,xn):
    plt.subplot(2,1,1)
    plt.plot(n[:50],xn[:50])
    plt.grid()
    plt.xlabel('t (tempo)')
    plt.ylabel('x(t)')

    plt.subplot(2,1,2)
    plt.stem(n[:50],xn[:50])
    plt.grid()
    plt.xlabel('t (tempo)')
    plt.ylabel('x[n]')
    return

# %%
def ctfts(x,T):
    N = len(x)
    X = np.fft.fftshift(np.fft.fft(x,N)*(2*np.pi/N))
    
    index1 = np.where(abs(X.real)<1)
    X.real[index1] = 0

    index2 = np.where(abs(X.imag)<1)
    X.imag[index2] = 0
    
    o = np.angle(X)
    A = np.abs(X)
    w = np.linspace(-1,1-1/N,N)/(2*T)
    
    #Plot de Amplitude e Fase da Transformada
    plt.subplot(2,1,1)
    plt.plot(w, A)
    plt.grid()
    plt.xlabel('w (frequência)')
    plt.ylabel('|X(e^jw)| (Amplitude)')

    plt.subplot(2,1,2)
    plt.plot(w, o)
    plt.grid()
    plt.xlabel('w (frequência)')
    plt.ylabel('<(X(e^jw)) (fase)')

    return A,o,w

# %%
#Gerando as amostras de x(t) para fo
n, xn = generator(2*np.pi*1000)

#Plotando x(t) e xn
plotting(n,xn)

# %%
#Transformada de Fourier de Tempo Continuo
mag,fase,w = ctfts(xn,1/8192)

# %%
#PARTE 2

# o0 = 1500
n1,xn1 =generator(2*np.pi*1500)
plotting(n1,xn1)

# %%
#Transformada de Fourier de Tempo Continuo
mag1,fase1,w = ctfts(xn1,1/8192)

# %%
#o0 = 2000
n2,xn2 =generator(2*np.pi*2000)
plotting(n2,xn2)

# %%
#Transformada de Fourier de Tempo Continuo
mag2,fase2,w = ctfts(xn2,1/8192)

# %%
#o0 = 3500
n3,xn3 =generator(2*np.pi*3500)
plotting(n3,xn3)

# %%
#Transformada de Fourier de Tempo Continuo
mag3,fase3,w = ctfts(xn3,1/8192)

# %%
#o0 = 4000
n4,xn4 =generator(2*np.pi*4000)
plotting(n4,xn4)

# %%
#Transformada de Fourier de Tempo Continuo
mag4,fase4,w = ctfts(xn4,1/8192)

# %%
#o0 = 4500
n5,xn5 =generator(2*np.pi*4500)
plotting(n5,xn5)

# %%
#Transformada de Fourier de Tempo Continuo
mag5,fase5,w = ctfts(xn5,1/8192)

# %%
#o0 = 5000
n6,xn6 =generator(2*np.pi*5000)
plotting(n6,xn6)

# %%
#Transformada de Fourier de Tempo Continuo
mag6,fase6,w = ctfts(xn6,1/8192)

# %%
#o0 = 5500
n7,xn7 =generator(2*np.pi*5500)
plotting(n7,xn7)

# %%
#Transformada de Fourier de Tempo Continuo
mag7,fase7,w = ctfts(xn7,1/8192)

# %%
from IPython.display import Audio
from scipy.io.wavfile import write

#Ouvindo os sinais da letra d)

#o0= 1500
write('sine.wav', 8192, xn1)
Audio(xn1,rate=8192)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#o0= 2000
write('sine.wav', 8192, xn2)
Audio(xn2,rate=8192)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#Ouvindo os sinais da letra f)

#o0 = 3500
write('sine.wav', 8192, xn3)
Audio(xn3,rate=8192)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#o0 = 3500
write('sine.wav', 8192, xn3)
Audio(xn3,rate=8192)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#o0 = 4000
write('sine.wav', 8192, xn4)
Audio(xn4,rate=8192)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#o0 = 4500
write('sine.wav', 8192, xn5)
Audio(xn5,rate=8192)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#o0 = 5000
write('sine.wav', 8192, xn6)
Audio(xn6,rate=8192)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#o0 = 5500
write('sine.wav', 8192, xn7)
Audio(xn7,rate=8192)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
